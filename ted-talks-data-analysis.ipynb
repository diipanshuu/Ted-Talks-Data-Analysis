# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\DIPANSHU\Downloads\data.csv')
print (df)
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %% [markdown]
# # To check whether there are null values or not in dataset.

# %%
df.isnull().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %% [markdown]
# # To Drop the Null Values from dataset.

# %%
df=df.dropna()

# %%
data = df.values

# %%
data[1][1]
# Out:
# 'Sydney Iaukea'

# %% [markdown]
# # FOR LOOP for all Authors in dataset.

# %%
author = []
for i in range(len(data)):
    author.append(data[i][1])

# %%
author
# Out:
# ['Ozawa Bineshi Albert',
#  'Sydney Iaukea',
#  'Martin Reeves',
#  'James K. Thornton',
#  'Mahendra Singhi',
#  'Rosamund Adoo-Kissi-Debrah',
#  'Iseult Gillespie',
#  'Gay Gordon-Byrne',
#  'Erin Meezan',
#  'Dwan Reece',
#  'Ian Kerner',
#  'Richard Browning',
#  'Daniel H. Pink',
#  'Lucas Joppa',
#  ' Belle and Sebastian',
#  'Mounia Akl',
#  'Yana Buhrer Tavanier',
#  'Susan Ruffo',
#  'Tim Dunn',
#  ' Let It Happen',
#  'Dave Matthews',
#  'Zoë Karl-Waithaka',
#  'Dan Kwartler',
#  'Dan Jørgensen',
#  'Lei Li',
#  'Nick Turner and Whitney Pennington Rodgers',
#  'Elizabeth Cox',
#  ' Kaz',
#  'Katie McGinty',
#  'Rachel Kyte',
#  'Katie Paterson',
#  'Emily Zobel Marshall',
#  'Deval Patrick',
#  'Rha Goddess and Deepa Purushothaman',
#  'Zac Goldsmith',
#  'Thomas W. Cronin',
#  'Gala Marija Vrbanic',
#  'Li-Huei Tsai',
#  'Emily Pilloton-Lam',
#  'Dustin Burke',
#  'Marie Brodsky',
#  'Gabrielle Walker',
#  'Reuben Jonathan Miller',
#  'Iseult Gillespie',
# ...

# %% [markdown]
# **Length of the authors but not unique.**

# %%
len(author)
# Out:
# 5439

# %% [markdown]
# # Total number of Authors.

# %%
author = set()
for i in range(len(data)):
    author.add(data[i][1])
    
print(len(author))
# Out:
# 4443

# %%
for i in range(len(data)):
    if(data[i][1] == 'Bill Gates'):
        print(data[i])
# Out:
# ['The innovations we need to avoid a climate disaster' 'Bill Gates'
#  'March 2021' 1700000 53000
#  'https://ted.com/talks/bill_gates_the_innovations_we_need_to_avoid_a_climate_disaster']
# ['How the pandemic will shape the near future' 'Bill Gates' 'June 2020'
#  4600000 138000
#  'https://ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future']
# ['How we must respond to the coronavirus pandemic' 'Bill Gates'
#  'March 2020' 8600000 259000
#  'https://ted.com/talks/bill_gates_how_we_must_respond_to_the_coronavirus_pandemic']
# ["The next outbreak? We're not ready" 'Bill Gates' 'March 2015' 43000000
#  1300000
#  'https://ted.com/talks/bill_gates_the_next_outbreak_we_re_not_ready']
# ['Teachers need real feedback' 'Bill Gates' 'May 2013' 4500000 135000
#  'https://ted.com/talks/bill_gates_teachers_need_real_feedback']
# ['How state budgets are breaking US schools' 'Bill Gates' 'March 2011'
#  2100000 63000
# ...

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
views = []
for i in range(len(data)):
    views.append(data[i][3])

# %% [markdown]
# # Total no. of views Ted Talks is having.

# %%
sum(views)
# Out:
# 11214972679

# %% [markdown]
# # Average view each Ted-Talk is having.

# %%
int(sum(views)/len(data))
# Out:
# 2061954

# %% [markdown]
# # Average no. of views each for Bill Gates Ted-Talk.

# %%
views = []
for i in range(len(data)):
    if(data[i][1] == 'Bill Gates'):
        views.append(data[i][3])

# %%
int(sum(views)/len(views))
# Out:
# 9725000

# %% [markdown]
# # Likes To View Ratio

# %%
view_to_like = []
for i in range(len(data)):
    view_to_like.append(int(data[i][3]/data[i][4]))

# %%
max(view_to_like)
# Out:
# 36

# %%
min(view_to_like)
# Out:
# 30

# %%
df['vtlr'] = view_to_like
# Out:
# C:\Users\DIPANSHU\AppData\Local\Temp\ipykernel_3740\3240412518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vtlr'] = view_to_like

# %% [markdown]
# # Ted-Talks of Bill Gates

# %%
int(df[df['author'] == 'Bill Gates']['views'].mean())
# Out:
# 9725000

# %%
df['author'].describe()
# Out:
# count             5439
# unique            4443
# top       Alex Gendler
# freq                45
# Name: author, dtype: object

# %% [markdown]
# # Topic search.

# %%
topic = 'black hole'

for i in range(len(data)):
    if(topic in data[i][0].lower()):
        print(data[i])
# Out:
# ['Could we harness the power of a black hole?' 'Fabio Pacucci'
#  'October 2020' 464000 13000
#  'https://ted.com/talks/fabio_pacucci_could_we_harness_the_power_of_a_black_hole']
# ["Hawking's black hole paradox explained" 'Fabio Pacucci' 'October 2019'
#  3100000 95000
#  'https://ted.com/talks/fabio_pacucci_hawking_s_black_hole_paradox_explained']
# ['The most detailed map of galaxies, black holes and stars ever made'
#  'Juna Kollmeier' 'April 2019' 2600000 80000
#  'https://ted.com/talks/juna_kollmeier_the_most_detailed_map_of_galaxies_black_holes_and_stars_ever_made']
# ['Can a black hole be destroyed?' 'Fabio Pacucci' 'May 2019' 1700000 51000
#  'https://ted.com/talks/fabio_pacucci_can_a_black_hole_be_destroyed']
# ['Inside the black hole image that made history' 'Sheperd Doeleman'
#  'April 2019' 3600000 108000
#  'https://ted.com/talks/sheperd_doeleman_inside_the_black_hole_image_that_made_history']
# ['Could the Earth be swallowed by a black hole?' 'Fabio Pacucci'
# ...
